# %%
import resspect
import pandas as pd
from resspect import request_TOM_data
from resspect import fit_TOM, fit
from resspect import submit_queries_to_TOM
from resspect import time_domain_loop
from resspect.tom_client import TomClient
from resspect import time_domain_loop
from resspect import TimeDomainConfiguration
import os
import re
import numpy as np

# %%
###🔲 Need to import this from RESSPECT
###🔲 Need to put this updated version in RESSPECT 
def update_pool_stash(day: int):
    #🔲check if a directory exists to contain features and if it doesn't, make it!
    outdir = 'TOM_days_storage'

    #should we store old features somewhere? makes it easier to add training objs
    #would want to add current MJD, maybe first MJD, and peak MJD
    if day!=0:
        current_stash_path = outdir+'/TOM_compiled_features_day'+str(day-1)+'.csv'
    elif day==0:
        current_stash_path = outdir+'/TOM_hot_features_day_'+str(day)+'.csv'
    
    new_night_path = outdir+'/TOM_hot_features_day_'+str(day)+'.csv'
    
    #read in current stash as list of strings
    with open(current_stash_path, 'r') as f:
        current_stash = f.readlines()
    #read in new night as list of strings
    with open(new_night_path, 'r') as f:
        new_night = f.readlines()

    curent_stash_df = pd.read_csv(current_stash_path)
    new_night_df = pd.read_csv(new_night_path)

    compiled_df = pd.concat([curent_stash_df,new_night_df]).drop_duplicates('id', keep='last')
    compiled_list = compiled_df.to_string(index=False).split('\n')
    compiled_comsep_list = [','.join(ele.split()) for ele in compiled_list]
    return_string = '\n'.join(compiled_comsep_list)

    output_path = outdir+'/TOM_compiled_features_day'+str(day)+'.csv'
    # rewrite the file 
    with open(output_path, 'w') as f:
        f.write(return_string)

# %%
#🔲 Need to remove no longer hot SN, will help speed things up
#🔲 in the mean time remove after 15 days
def remove_from_pool_stash(day):
    #🔲check if a directory exists to contain features and if it doesn't, make it!
    outdir = 'TOM_days_storage'
    current_stash_path = outdir+'/TOM_hot_features_day_'+str(day)+'.csv'
    
    #read in current stash as list of strings
    with open(current_stash_path, 'r') as f:
        current_stash = f.readlines()
    
    curent_stash_df = pd.read_csv(current_stash_path)


    #🔲 Need to remove old obj
    remove_old_obj_df = current_stash_df[current_stash_df["date_added"] > day-15]

    removed_list = remove_old_obj_df.to_string(index=False).split('\n')
    removed_comsep_list = [','.join(ele.split()) for ele in removed_list]
    return_string = '\n'.join(removed_comsep_list)

    output_path = outdir+'/TOM_compiled_features_day'+str(day)+'.csv'
    #gotta rewrite the file dummy
    with open(output_path, 'w') as f:
        f.write(return_string)

# %%
additional_info = [
        'hostgal_snsep',
        'hostgal_ellipticity',
        'hostgal_sqradius',
        'hostgal_mag_u',
        'hostgal_mag_g',
        'hostgal_mag_r',
        'hostgal_mag_i',
        'hostgal_mag_z',
        'hostgal_mag_y',
        'hostgal_magerr_u',
        'hostgal_magerr_g',
        'hostgal_magerr_r',
        'hostgal_magerr_i',
        'hostgal_magerr_z',
        'hostgal_magerr_y',
    ]

from laiss_resspect_classifier.elasticc2_laiss_feature_extractor import Elasticc2LaissFeatureExtractor

def validate_objects(objects_to_test):
    fe = Elasticc2LaissFeatureExtractor()
    good_objs = []

    for t_obj in objects_to_test:
        fe.photometry= pd.DataFrame(t_obj['photometry'])
        fe.id = t_obj['objectid']

        fe.additional_info = {}
        for info in additional_info:
            fe.additional_info[info] = t_obj[info]

        res = fe.fit_all()
        if res:
            good_objs.append(t_obj)

    return good_objs

# %%
def get_phot(obj_df):

    tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = 'awoldag', passwordfile = '../../password.txt')

    # get all of the photometry at once
    ids = obj_df['diaobject_id'].tolist()
    res = tom.post('db/runsqlquery/',
                          json={ 'query': 'SELECT diaobject_id, filtername, midpointtai, psflux, psfluxerr'  
                                ' FROM elasticc2_ppdbdiaforcedsource' 
                              ' WHERE diaobject_id IN (%s) ORDER BY diaobject_id, filtername, midpointtai;' % (', '.join(str(id) for id in ids)),
                                'subdict': {} } )
    all_phot = res.json()['rows']
    all_phot_df = pd.DataFrame(all_phot)
    # if you need mag from the arbitrary flux-
    all_phot_df['mag'] = -2.5*np.log10(all_phot_df['psflux']) + 27.5
    all_phot_df['magerr'] = 2.5/np.log(10) * all_phot_df['psfluxerr']/all_phot_df['psflux']

    #! Need to send Rob a message to ask that these features be included when querying for hot super nova
    host_res = tom.post('db/runsqlquery/',
                          json={ 'query': 'SELECT diaobject_id, hostgal_mag_u, hostgal_mag_g, hostgal_mag_r, hostgal_mag_i, hostgal_mag_z, hostgal_mag_Y, hostgal_magerr_u, hostgal_magerr_g, hostgal_magerr_r, hostgal_magerr_i, hostgal_magerr_z, hostgal_magerr_Y, hostgal_snsep, hostgal_ellipticity, hostgal_sqradius'
                                ' FROM elasticc2_ppdbdiaobject'
                              ' WHERE diaobject_id IN (%s) ORDER BY diaobject_id;' % (', '.join(str(id) for id in ids)),
                                'subdict': {} } )
    all_host = host_res.json()['rows']


    # format into a list of dicts
    data = []
    for idx, obj in obj_df.iterrows():
        phot = all_phot_df[all_phot_df['diaobject_id'] == obj['diaobject_id']]

        phot_d = {}
        phot_d['objectid'] = int(obj['diaobject_id'])
        phot_d['sncode'] = int(obj['gentype'])
        phot_d['redshift'] = obj['zcmb']
        phot_d['ra'] = obj['ra']
        phot_d['dec'] = obj['dec']
        phot_d['photometry'] = phot[['filtername', 'midpointtai', 'psflux', 'psfluxerr', 'mag', 'magerr']].to_dict(orient='list')

        phot_d['photometry']['band'] = phot_d['photometry']['filtername']
        phot_d['photometry']['mjd'] = phot_d['photometry']['midpointtai']
        phot_d['photometry']['flux'] = phot_d['photometry']['psflux']
        phot_d['photometry']['fluxerr'] = phot_d['photometry']['psfluxerr']
        phot_d['photometry']['mag'] = phot_d['photometry']['mag']
        phot_d['photometry']['magerr'] = phot_d['photometry']['magerr']
        del phot_d['photometry']['filtername']
        del phot_d['photometry']['midpointtai']
        del phot_d['photometry']['psflux']
        del phot_d['photometry']['psfluxerr']
        phot_d = {**phot_d, **all_host[idx]}
        del phot_d['diaobject_id']
        data.append(phot_d)

    return data

# %%
def get_phot_orig(obj_df):
    # get all of the photometry at once
    ids = obj_df['diaobject_id'].tolist()
    res = tom.post('db/runsqlquery/',
                          json={ 'query': 'SELECT diaobject_id, filtername, midpointtai, psflux, psfluxerr'  
                                ' FROM elasticc2_ppdbdiaforcedsource' 
                              ' WHERE diaobject_id IN (%s) ORDER BY diaobject_id, filtername, midpointtai;' % (', '.join(str(id) for id in ids)),
                                'subdict': {} } )
    all_phot = res.json()['rows']
    all_phot_df = pd.DataFrame(all_phot)
    # if you need mag from the arbitrary flux
    # all_phot_df['mag'] = -2.5*np.log10(all_phot_df['psflux']) + 27.5
    # all_phot_df['magerr'] = 2.5/np.log(10) * all_phot_df['psfluxerr']/all_phot_df['psflux']

    # format into a list of dicts
    data = []
    for idx, obj in obj_df.iterrows():
        phot = all_phot_df[all_phot_df['diaobject_id'] == obj['diaobject_id']]
        
        phot_d = {}
        phot_d['objectid'] = int(obj['diaobject_id'])
        phot_d['sncode'] = int(obj['gentype'])
        phot_d['redshift'] = obj['zcmb']
        phot_d['ra'] = obj['ra']
        phot_d['dec'] = obj['dec']
        phot_d['photometry'] = phot[['filtername', 'midpointtai', 'psflux', 'psfluxerr']].to_dict(orient='list')

        phot_d['photometry']['band'] = phot_d['photometry']['filtername']
        phot_d['photometry']['mjd'] = phot_d['photometry']['midpointtai']
        phot_d['photometry']['flux'] = phot_d['photometry']['psflux']
        phot_d['photometry']['fluxerr'] = phot_d['photometry']['psfluxerr']
        del phot_d['photometry']['filtername']
        del phot_d['photometry']['midpointtai']
        del phot_d['photometry']['psflux']
        del phot_d['photometry']['psfluxerr']
        
        data.append(phot_d)

    return data

# %%
#MAKE INITIAL TRAINING SET 
objs = []

tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = 'awoldag', passwordfile = '../../password.txt')

res = tom.post('db/runsqlquery/',
                        json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                              ' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61300 and peakmjd<61309 and gentype=10 limit 10;', 
                             'subdict': {}} )
objs.extend(res.json()['rows'])
gentypes = [20,21,25,26,27,12,40,42,59]
for gentype in gentypes:
    res = tom.post('db/runsqlquery/',
                            json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                                f' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61300 and peakmjd<61309 and gentype={gentype} limit 5;', 
                                'subdict': {}} )
    objs.extend(res.json()['rows'])

training_objs = get_phot(pd.DataFrame(objs))
good_objs = validate_objects(training_objs)

outdir = 'TOM_days_storage'

if not os.path.exists(outdir):
    os.makedirs(outdir)

feature_extraction_method = 'laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor'
fit(
    good_objs,
    output_features_file = outdir+'/TOM_training_features',
    feature_extractor = feature_extraction_method,
    filters='ZTF',
    additional_info=additional_info,
    one_code=gentypes,
)
data = pd.read_csv('TOM_days_storage/TOM_training_features',index_col=False)
data['orig_sample'] = 'train'
data["type"] = np.where(data["sncode"] == 10, 'Ia', 'other')
data.to_csv('TOM_days_storage/TOM_training_features',index=False)
# Out:
# Not enough obs for 123240715. pass!
# INFO:root:Starting laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor fit...
# INFO:root:Features have been saved to: TOM_days_storage/TOM_training_features

# %%
#MAKE TEST SET 
objs = []

tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = 'awoldag', passwordfile = '../../password.txt')

res = tom.post('db/runsqlquery/',
                        json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                              ' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61310 and peakmjd<61339 and gentype=10 limit 1000;', 
                             'subdict': {}} )
objs.extend(res.json()['rows'])

gentypes = [20,21,25,26,27,12,40,42,59]
for gentype in gentypes:
      res = tom.post('db/runsqlquery/',
                              json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                                    f' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61310 and peakmjd<61339 and gentype = {gentype} limit 100;', 
                              'subdict': {}} )
      objs.extend(res.json()['rows'])

test_objs = get_phot(pd.DataFrame(objs))
good_objs = validate_objects(test_objs)

outdir = 'TOM_days_storage'

if not os.path.exists(outdir):
    os.makedirs(outdir)

feature_extraction_method = 'laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor'
fit(
    good_objs,
    output_features_file = outdir+'/TOM_testing_features',
    feature_extractor = feature_extraction_method,
    filters='ZTF',
    additional_info=additional_info,
    one_code=gentypes,
)
data = pd.read_csv('TOM_days_storage/TOM_testing_features',index_col=False)
data['orig_sample'] = 'train'
data["type"] = np.where(data["sncode"] == 10, 'Ia', 'other')
data.to_csv('TOM_days_storage/TOM_testing_features',index=False)
# Out:
# Not enough obs for 100502727. pass!
#
# Not enough obs for 33733016. pass!
#
# Not enough obs for 64472383. pass!
#
# Not enough obs for 87617224. pass!
#
# Not enough obs for 152063486. pass!
#
# Not enough obs for 4372763. pass!
#
# Not enough obs for 19887951. pass!
#
# Not enough obs for 109897362. pass!
#
# Not enough obs for 18002946. pass!
#
# Not enough obs for 34126804. pass!
#
# Not enough obs for 102390903. pass!
#
# Not enough obs for 31324487. pass!
#
# Not enough obs for 107621693. pass!
#
# Not enough obs for 75052665. pass!
#
# Not enough obs for 129794122. pass!
#
# Not enough obs for 51185706. pass!
#
# Not enough obs for 159131060. pass!
#
# Not enough obs for 153015355. pass!
#
# Not enough obs for 154313091. pass!
#
# Not enough obs for 12966687. pass!
#
# Not enough obs for 1041473. pass!
#
# Not enough obs for 158241304. pass!
#
# Not enough obs for 112705885. pass!
#
# Not enough obs for 44701642. pass!
#
# Not enough obs for 59852840. pass!
#
# Not enough obs for 65980131. pass!
#
# Not enough obs for 151770909. pass!
#
# Not enough obs for 138353966. pass!
#
# Not enough obs for 120800653. pass!
#
# Not enough obs for 78129485. pass!
#
# Not enough obs for 93808423. pass!
#
# Not enough obs for 18646418. pass!
#
# Not enough obs for 100311542. pass!
#
# Not enough obs for 61180027. pass!
#
# Not enough obs for 45560195. pass!
#
# Not enough obs for 4658151. pass!
#
# Not enough obs for 105999326. pass!
#
# Not enough obs for 64618002. pass!
#
# Not enough obs for 104847687. pass!
#
# Not enough obs for 13294001. pass!
#
# Not enough obs for 101601442. pass!
#
# Not enough obs for 57357868. pass!
#
# Not enough obs for 88555317. pass!
#
# Not enough obs for 26618909. pass!
#
# Not enough obs for 115106092. pass!
#
# Not enough obs for 135254099. pass!
#
# Not enough obs for 115246251. pass!
# INFO:root:Starting laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor fit...
# INFO:root:Features have been saved to: TOM_days_storage/TOM_testing_features

# %%
#✅ MAKE VALIDATION SET 
objs = []

tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = 'awoldag', passwordfile = '../../password.txt')

res = tom.post('db/runsqlquery/',
                        json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                              ' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61340 and gentype=10 limit 1000;', 
                             'subdict': {}} )
objs.extend(res.json()['rows'])

gentypes = [20,21,25,26,27,12,40,42,59]
for gentype in gentypes:
    res = tom.post('db/runsqlquery/',
                            json={ 'query': 'SELECT diaobject_id, gentype, zcmb, peakmjd,' 
                                f' peakmag_g, ra, dec FROM elasticc2_diaobjecttruth WHERE peakmjd>61340 and gentype={gentype} limit 100;', 
                                'subdict': {}} )
    objs.extend(res.json()['rows'])

val_objs = get_phot(pd.DataFrame(objs))
good_objs = validate_objects(val_objs)

outdir = 'TOM_days_storage'

if not os.path.exists(outdir):
    os.makedirs(outdir)

feature_extraction_method = 'laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor'
fit(
    good_objs,
    output_features_file = outdir+'/TOM_validation_features',
    feature_extractor = feature_extraction_method,
    filters='ZTF',
    additional_info=additional_info,
    one_code=gentypes,
)
data = pd.read_csv('TOM_days_storage/TOM_validation_features',index_col=False)
data['orig_sample'] = 'train'
data["type"] = np.where(data["sncode"] == 10, 'Ia', 'other')
data.to_csv('TOM_days_storage/TOM_validation_features',index=False)
# Out:
# Not enough obs for 44800973. pass!
#
# Not enough obs for 141328782. pass!
#
# Not enough obs for 61302065. pass!
#
# Not enough obs for 87291295. pass!
#
# Not enough obs for 19117780. pass!
#
# Not enough obs for 80604681. pass!
#
# Not enough obs for 128592939. pass!
#
# Not enough obs for 39828597. pass!
#
# Not enough obs for 79426686. pass!
#
# Not enough obs for 60472694. pass!
#
# Not enough obs for 73972283. pass!
#
# Not enough obs for 154941717. pass!
#
# Not enough obs for 104754364. pass!
#
# Not enough obs for 61547230. pass!
#
# Not enough obs for 148885626. pass!
#
# Not enough obs for 40839889. pass!
#
# Not enough obs for 5650186. pass!
#
# Not enough obs for 46540052. pass!
#
# Not enough obs for 54402381. pass!
#
# Not enough obs for 94323582. pass!
#
# Not enough obs for 152848675. pass!
#
# Not enough obs for 43378718. pass!
#
# Not enough obs for 146319328. pass!
#
# Not enough obs for 105173195. pass!
#
# Not enough obs for 142460430. pass!
#
# Not enough obs for 129186952. pass!
#
# Not enough obs for 14487438. pass!
#
# Not enough obs for 34300119. pass!
#
# Not enough obs for 157632923. pass!
#
# Not enough obs for 70660811. pass!
#
# Not enough obs for 141621992. pass!
#
# Not enough obs for 117278301. pass!
#
# Not enough obs for 134639136. pass!
#
# Not enough obs for 120290244. pass!
#
# Not enough obs for 50360411. pass!
#
# Not enough obs for 114495184. pass!
#
# Not enough obs for 117762090. pass!
#
# Not enough obs for 31137082. pass!
#
# Not enough obs for 58181118. pass!
#
# Not enough obs for 127541028. pass!
#
# Not enough obs for 109892994. pass!
#
# Not enough obs for 128019080. pass!
#
# Not enough obs for 141190884. pass!
#
# Not enough obs for 142548886. pass!
#
# Not enough obs for 73438950. pass!
#
# Not enough obs for 64116338. pass!
#
# Not enough obs for 44876139. pass!
#
# Not enough obs for 64793212. pass!
#
# Not enough obs for 148000495. pass!
#
# Not enough obs for 53476798. pass!
#
# Not enough obs for 62593670. pass!
#
# Not enough obs for 110571799. pass!
#
# Not enough obs for 159170557. pass!
#
# Not enough obs for 144408495. pass!
#
# Not enough obs for 7388314. pass!
#
# Not enough obs for 138480629. pass!
#
# Not enough obs for 39920626. pass!
#
# Not enough obs for 82807033. pass!
#
# Not enough obs for 19541112. pass!
#
# Not enough obs for 143843584. pass!
# Not enough obs for 31707092. pass!
#
# Not enough obs for 117214340. pass!
#
# Not enough obs for 81574762. pass!
#
# Not enough obs for 110402143. pass!
#
# Not enough obs for 87265483. pass!
#
# Not enough obs for 43701267. pass!
#
# Not enough obs for 125749829. pass!
#
# Not enough obs for 27925930. pass!
#
# Not enough obs for 35370497. pass!
#
# Not enough obs for 151257883. pass!
#
# Not enough obs for 152022862. pass!
#
# Not enough obs for 47664366. pass!
#
# Not enough obs for 98546302. pass!
#
# Not enough obs for 143471405. pass!
#
# Not enough obs for 28392560. pass!
#
# Not enough obs for 26357229. pass!
#
# Not enough obs for 133021386. pass!
#
# Not enough obs for 154592387. pass!
#
# Not enough obs for 87420544. pass!
#
# Not enough obs for 123647765. pass!
#
# Not enough obs for 34638299. pass!
#
# Not enough obs for 114262438. pass!
#
# Not enough obs for 100053638. pass!
#
# Not enough obs for 96616571. pass!
#
# Not enough obs for 94819439. pass!
#
# Not enough obs for 74732939. pass!
#
# Not enough obs for 16783161. pass!
#
# Not enough obs for 17125146. pass!
#
# Not enough obs for 4150333. pass!
#
# Not enough obs for 101833429. pass!
#
# Not enough obs for 14385733. pass!
#
# Not enough obs for 70069519. pass!
#
# Not enough obs for 126734102. pass!
#
# Not enough obs for 105622615. pass!
#
# Not enough obs for 48352054. pass!
#
# Not enough obs for 140284881. pass!
#
# Not enough obs for 33224543. pass!
#
# Not enough obs for 107925429. pass!
#
# Not enough obs for 68123059. pass!
#
# Not enough obs for 93884995. pass!
#
# Not enough obs for 109535895. pass!
#
# Not enough obs for 22953451. pass!
#
# Not enough obs for 114954711. pass!
#
# Not enough obs for 61024016. pass!
#
# Not enough obs for 38973635. pass!
#
# Not enough obs for 23500040. pass!
#
# Not enough obs for 152424410. pass!
#
# Not enough obs for 142043978. pass!
#
# Not enough obs for 76284333. pass!
#
# Not enough obs for 7470952. pass!
#
# Not enough obs for 130000617. pass!
#
# Not enough obs for 151912440. pass!
#
# Not enough obs for 142688939. pass!
#
# Not enough obs for 90253865. pass!
#
# Not enough obs for 104463852. pass!
#
# Not enough obs for 6565254. pass!
#
# Not enough obs for 115405188. pass!
#
# Not enough obs for 132651908. pass!
#
# Not enough obs for 16319984. pass!
#
# Not enough obs for 140482345. pass!
#
# Not enough obs for 132879932. pass!
#
# Not enough obs for 18526484. pass!
#
# Not enough obs for 23720233. pass!
#
# Not enough obs for 117926972. pass!
#
# Not enough obs for 5763678. pass!
#
# Not enough obs for 10898243. pass!
#
# Not enough obs for 91607839. pass!
#
# Not enough obs for 6856136. pass!
#
# Not enough obs for 49750503. pass!
#
# Not enough obs for 111743096. pass!
#
# Not enough obs for 150015797. pass!
#
# Not enough obs for 134354532. pass!
#
# Not enough obs for 19217116. pass!
#
# Not enough obs for 33663082. pass!
#
# Not enough obs for 38773515. pass!
#
# Not enough obs for 36159832. pass!
#
# Not enough obs for 7251092. pass!
#
# Not enough obs for 42207713. pass!
#
# Not enough obs for 106287145. pass!
#
# Not enough obs for 116013589. pass!
#
# Not enough obs for 5319540. pass!
#
# Not enough obs for 39840133. pass!
#
# Not enough obs for 13770441. pass!
#
# Not enough obs for 138486428. pass!
#
# Not enough obs for 99584016. pass!
#
# Not enough obs for 1880829. pass!
#
# Not enough obs for 56837767. pass!
# INFO:root:Starting laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor fit...
# INFO:root:Features have been saved to: TOM_days_storage/TOM_validation_features

# %%
def run_one_night(day):    
                            #🔲 check for new spec+classification for training set before running the loop
    #✅flag for simulated vs real data
                            #🔲implement an auto-check
    #✅first thing, check if it's real or sim data
                            #🔲MAKE CLEAR WHAT IS FOR REAL DATA VS SIM (eg. real data will want date)
    #✅request light curve data from the TOM - for real and simulated
    
    #get new lc info from TOM (from yesterday (for now))
    # data_dic = request_TOM_data(url = "https://desc-tom-2.lbl.gov", username='awoldag',
    #                             passwordfile='../../password.txt', detected_in_last_days = 1,
    #                             mjdnow = 60796+day-1, cheat_gentypes = [82, 10, 21, 27, 26, 37, 32, 36, 31, 89])
    data_dic = request_TOM_data(url = "https://desc-tom-2.lbl.gov", username='awoldag',
                            passwordfile='../../password.txt', detected_in_last_days = 1,
                            mjdnow = 60796+day-1, cheat_gentypes = [20,21,25,26,27,12,40,42,59,10,30,31,32,35,36,37,11])
    
    data_dic=data_dic['diaobject']

    good_dic = validate_objects(data_dic)

    # feature_extraction_method = 'Malanchev'
    feature_extraction_method = 'laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor'
    # classifier = 'RandomForest'
    classifier = 'laiss_resspect_classifier.laiss_classifier.LaissRandomForest'

    #✅run that data through RESSPECT to get features
                            #🔲at some point, cut out objects that are not likely SN - do this before it gets to RESSPECT probably
    #✅clarify out file argument/data base


    #    if day >= 0:
#        file_name = outdir+'/TOM_hot_features_day_'+str(day)+'.csv'
#    else:
#        file_name = outdir+'/TOM_hot_features.csv'
    
    #get features from that data
    outdir = 'TOM_days_storage'
    file_name = outdir+'/TOM_hot_features_day_'+str(day-1)+'.csv'
        
    fit(
        good_dic,
        output_features_file = file_name,
        feature_extractor = feature_extraction_method,
        filters='ZTF',
        additional_info=additional_info
    )
    data = pd.read_csv(file_name, index_col=False)
    data['orig_sample'] = 'pool'
    #add date added so that we can remove when they are too old

    
    data.to_csv(file_name,index=False)

    # -------------------------

    #get new lc info from TOM (for today)
    # data_dic = request_TOM_data(url = "https://desc-tom-2.lbl.gov",username='awoldag',
    #                             passwordfile='../../../password.txt',detected_in_last_days = 1, mjdnow = 60796+day, 
    #                             cheat_gentypes = [82, 10, 21, 27, 26, 37, 32, 36, 31, 89])
    data_dic = request_TOM_data(url = "https://desc-tom-2.lbl.gov",username='awoldag',
                            passwordfile='../../password.txt',detected_in_last_days = 1, mjdnow = 60796+day, 
                            cheat_gentypes = [20,21,25,26,27,12,40,42,59,10,30,31,32,35,36,37,11])
    data_dic=data_dic['diaobject']
    good_dic = validate_objects(data_dic)
    #get features from that data
    outdir = 'TOM_days_storage'
    file_name = outdir+'/TOM_hot_features_day_'+str(day)+'.csv'
        
    fit(
        good_dic,
        output_features_file = file_name,
        feature_extractor = feature_extraction_method,
        filters='ZTF',
        additional_info=additional_info,
    )
    data = pd.read_csv(file_name, index_col=False)
    data['orig_sample'] = 'pool'
    
    data.to_csv(file_name,index=False)

# %%
run_one_night(50)
# Out:
# Not enough obs for 1002404. pass!
#
# Not enough obs for 1003512. pass!
#
# Not enough obs for 1019009. pass!
#
# Not enough obs for 1021179. pass!
#
# Not enough obs for 1026842. pass!
#
# Not enough obs for 1028303. pass!
#
# Not enough obs for 1035697. pass!
#
# Not enough obs for 1050528. pass!
#
# Not enough obs for 1105973. pass!
#
# Not enough obs for 1113532. pass!
#
# Not enough obs for 1125508. pass!
#
# Not enough obs for 1134770. pass!
#
# Not enough obs for 1136228. pass!
#
# Not enough obs for 1146088. pass!
#
# Not enough obs for 1165184. pass!
#
# Not enough obs for 1203931. pass!
#
# Not enough obs for 1236407. pass!
#
# Not enough obs for 1236491. pass!
#
# Not enough obs for 1237363. pass!
#
# Not enough obs for 1238294. pass!
#
# Not enough obs for 1238968. pass!
#
# Not enough obs for 1245276. pass!
#
# Not enough obs for 1247881. pass!
#
# Not enough obs for 1251123. pass!
#
# Not enough obs for 1252493. pass!
#
# Not enough obs for 1279764. pass!
#
# Not enough obs for 1289503. pass!
#
# Not enough obs for 1301477. pass!
#
# Not enough obs for 1301784. pass!
#
# Not enough obs for 1312669. pass!
#
# Not enough obs for 1317173. pass!
#
# Not enough obs for 1320287. pass!
#
# Not enough obs for 1321489. pass!
#
# Not enough obs for 1337716. pass!
#
# Not enough obs for 1343896. pass!
#
# Not enough obs for 1345975. pass!
#
# Not enough obs for 1350220. pass!
#
# Not enough obs for 1362395. pass!
#
# Not enough obs for 1370907. pass!
#
# Not enough obs for 1372297. pass!
#
# Not enough obs for 1375790. pass!
#
# Not enough obs for 1380660. pass!
#
# Not enough obs for 1385575. pass!
#
# Not enough obs for 1409801. pass!
#
# Not enough obs for 1429773. pass!
#
# Not enough obs for 1433798. pass!
#
# Not enough obs for 1435257. pass!
#
# Not enough obs for 1444296. pass!
#
# Not enough obs for 1445227. pass!
#
# Not enough obs for 1450206. pass!
#
# Not enough obs for 1457149. pass!
#
# Not enough obs for 1463542. pass!
#
# Not enough obs for 1468644. pass!
#
# Not enough obs for 1477851. pass!
#
# Not enough obs for 1480236. pass!
#
# Not enough obs for 1486789. pass!
#
# Not enough obs for 1496780. pass!
#
# Not enough obs for 1508209. pass!
#
# Not enough obs for 1509251. pass!
#
# Not enough obs for 1511917. pass!
#
# Not enough obs for 1517998. pass!
#
# Not enough obs for 1526481. pass!
#
# Not enough obs for 1535750. pass!
#
# Not enough obs for 1548200. pass!
#
# Not enough obs for 1548263. pass!
#
# Not enough obs for 1549992. pass!
#
# Not enough obs for 1550094. pass!
#
# Not enough obs for 1557327. pass!
#
# Not enough obs for 1564004. pass!
#
# Not enough obs for 1568575. pass!
#
# Not enough obs for 1569123. pass!
#
# Not enough obs for 1581532. pass!
#
# Not enough obs for 1606254. pass!
#
# Not enough obs for 1615714. pass!
#
# Not enough obs for 1624983. pass!
#
# Not enough obs for 1628344. pass!
# Not enough obs for 4852945. pass!
#
# Not enough obs for 4862028. pass!
#
# Not enough obs for 4873955. pass!
#
# Not enough obs for 4891903. pass!
#
# Not enough obs for 4896220. pass!
#
# Not enough obs for 4917623. pass!
#
# Not enough obs for 4936575. pass!
#
# Not enough obs for 4941689. pass!
#
# Not enough obs for 4953166. pass!
#
# Not enough obs for 4955648. pass!
#
# Not enough obs for 4960008. pass!
#
# Not enough obs for 4960990. pass!
#
# Not enough obs for 4972353. pass!
#
# Not enough obs for 4975149. pass!
#
# Not enough obs for 4976384. pass!
#
# Not enough obs for 4983668. pass!
#
# Not enough obs for 4987021. pass!
#
# Not enough obs for 4988625. pass!
#
# Not enough obs for 4997300. pass!
#
# Not enough obs for 5018321. pass!
#
# Not enough obs for 5020337. pass!
#
# Not enough obs for 5026065. pass!
#
# Not enough obs for 5039637. pass!
#
# Not enough obs for 5054023. pass!
#
# Not enough obs for 5076333. pass!
#
# Not enough obs for 5080901. pass!
#
# Not enough obs for 5081707. pass!
#
# Not enough obs for 5089419. pass!
#
# Not enough obs for 5102116. pass!
#
# Not enough obs for 5103040. pass!
#
# Not enough obs for 5106186. pass!
#
# Not enough obs for 5112889. pass!
#
# Not enough obs for 5119648. pass!
#
# Not enough obs for 5124474. pass!
#
# Not enough obs for 5130992. pass!
#
# Not enough obs for 5135077. pass!
#
# Not enough obs for 5144403. pass!
#
# Not enough obs for 5148646. pass!
#
# Not enough obs for 5175707. pass!
#
# Not enough obs for 5176659. pass!
#
# Not enough obs for 5177919. pass!
#
# Not enough obs for 5184195. pass!
#
# Not enough obs for 5184972. pass!
#
# Not enough obs for 5196776. pass!
#
# Not enough obs for 5204894. pass!
#
# Not enough obs for 5216487. pass!
#
# Not enough obs for 5230867. pass!
#
# Not enough obs for 5231120. pass!
#
# Not enough obs for 5233580. pass!
#
# Not enough obs for 5235715. pass!
#
# Not enough obs for 5250462. pass!
#
# Not enough obs for 5260993. pass!
#
# Not enough obs for 5263854. pass!
#
# Not enough obs for 5264529. pass!
#
# Not enough obs for 5275583. pass!
#
# Not enough obs for 5289964. pass!
#
# Not enough obs for 5296730. pass!
#
# Not enough obs for 5328440. pass!
#
# Not enough obs for 5334259. pass!
#
# Not enough obs for 5341707. pass!
#
# Not enough obs for 5344669. pass!
#
# Not enough obs for 5367830. pass!
#
# Not enough obs for 5370351. pass!
#
# Not enough obs for 5372825. pass!
#
# Not enough obs for 5380191. pass!
#
# Not enough obs for 5396150. pass!
#
# Not enough obs for 5396938. pass!
#
# Not enough obs for 5397764. pass!
#
# Not enough obs for 5408563. pass!
#
# Not enough obs for 5427515. pass!
#
# Not enough obs for 5431278. pass!
#
# Not enough obs for 5435566. pass!
#
# Not enough obs for 5439223. pass!
#
# Not enough obs for 5456557. pass!
#
# Not enough obs for 5458718. pass!
#
# Not enough obs for 5460644. pass!
#
# Not enough obs for 5473717. pass!
#
# Not enough obs for 5475678. pass!
#
# Not enough obs for 5484134. pass!
#
# Not enough obs for 5494725. pass!
#
# Not enough obs for 5495117. pass!
#
# Not enough obs for 5520054. pass!
#
# Not enough obs for 5522825. pass!
#
# Not enough obs for 5527889. pass!
#
# Not enough obs for 5548979. pass!
#
# Not enough obs for 5559597. pass!
#
# Not enough obs for 5568123. pass!
#
# Not enough obs for 5575633. pass!
#
# Not enough obs for 5591427. pass!
#
# Not enough obs for 5595146. pass!
#
# Not enough obs for 5616588. pass!
#
# Not enough obs for 5618021. pass!
#
# Not enough obs for 5618598. pass!
#
# Not enough obs for 5626756. pass!
#
# Not enough obs for 5634018. pass!
#
# Not enough obs for 5646374. pass!
#
# Not enough obs for 5647976. pass!
#
# Not enough obs for 5659487. pass!
#
# Not enough obs for 5672077. pass!
#
# Not enough obs for 5677777. pass!
#
# Not enough obs for 5683290. pass!
#
# Not enough obs for 5687062. pass!
#
# Not enough obs for 5695927. pass!
#
# Not enough obs for 5701075. pass!
#
# Not enough obs for 5701322. pass!
#
# Not enough obs for 5712040. pass!
#
# Not enough obs for 5724591. pass!
#
# Not enough obs for 5768775. pass!
#
# Not enough obs for 5784971. pass!
#
# Not enough obs for 5786314. pass!
#
# Not enough obs for 5801704. pass!
#
# Not enough obs for 5803577. pass!
#
# Not enough obs for 5806904. pass!
#
# Not enough obs for 5812098. pass!
#
# Not enough obs for 5841270. pass!
#
# Not enough obs for 5844313. pass!
#
# Not enough obs for 5844451. pass!
#
# Not enough obs for 5847383. pass!
#
# Not enough obs for 5850521. pass!
#
# Not enough obs for 5877631. pass!
#
# Not enough obs for 5880103. pass!
#
# Not enough obs for 5885148. pass!
#
# Not enough obs for 5885748. pass!
#
# Not enough obs for 5892403. pass!
#
# Not enough obs for 5900645. pass!
#
# Not enough obs for 5904215. pass!
#
# Not enough obs for 5915769. pass!
#
# Not enough obs for 5922655. pass!
#
# Not enough obs for 5955670. pass!
#
# Not enough obs for 5957135. pass!
#
# Not enough obs for 5960942. pass!
#
# Not enough obs for 5966268. pass!
#
# Not enough obs for 5967353. pass!
#
# Not enough obs for 5999532. pass!
#
# Not enough obs for 6001201. pass!
#
# Not enough obs for 6002901. pass!
#
# Not enough obs for 6011220. pass!
#
# Not enough obs for 6033758. pass!
#
# Not enough obs for 6038470. pass!
#
# Not enough obs for 6041689. pass!
#
# Not enough obs for 6046710. pass!
#
# Not enough obs for 6052654. pass!
#
# Not enough obs for 6067571. pass!
#
# Not enough obs for 6073097. pass!
#
# Not enough obs for 6073502. pass!
#
# Not enough obs for 6075727. pass!
#
# Not enough obs for 6089734. pass!
#
# Not enough obs for 6098522. pass!
#
# Not enough obs for 6103107. pass!
#
# Not enough obs for 6115794. pass!
#
# Not enough obs for 6123833. pass!
#
# Not enough obs for 6126678. pass!
#
# Not enough obs for 6126936. pass!
#
# Not enough obs for 6132261. pass!
#
# Not enough obs for 6133802. pass!
#
# Not enough obs for 6145706. pass!
#
# Not enough obs for 6147876. pass!
#
# Not enough obs for 6151286. pass!
#
# Not enough obs for 6156028. pass!
#
# Not enough obs for 6160062. pass!
#
# Not enough obs for 6165427. pass!
#
# Not enough obs for 6167351. pass!
#
# Not enough obs for 6167840. pass!
#
# Not enough obs for 6187723. pass!
#
# Not enough obs for 6196846. pass!
#
# Not enough obs for 6201550. pass!
#
# Not enough obs for 6207546. pass!
#
# Not enough obs for 6227203. pass!
#
# Not enough obs for 6228241. pass!
#
# Not enough obs for 6229540. pass!
#
# Not enough obs for 6243941. pass!
#
# Not enough obs for 6245703. pass!
#
# Not enough obs for 6249148. pass!
#
# Not enough obs for 6250687. pass!
#
# Not enough obs for 6263569. pass!
#
# Not enough obs for 6272110. pass!
#
# Not enough obs for 6281523. pass!
#
# Not enough obs for 6283143. pass!
#
# Not enough obs for 6283512. pass!
#
# Not enough obs for 6300774. pass!
#
# Not enough obs for 6309626. pass!
#
# Not enough obs for 6310118. pass!
#
# Not enough obs for 6313957. pass!
#
# Not enough obs for 6324422. pass!
#
# Not enough obs for 6347146. pass!
#
# Not enough obs for 6350137. pass!
#
# Not enough obs for 6355491. pass!
#
# Not enough obs for 6356870. pass!
#
# Not enough obs for 6357570. pass!
#
# Not enough obs for 6372269. pass!
#
# Not enough obs for 6391956. pass!
#
# Not enough obs for 6396488. pass!
#
# Not enough obs for 6401567. pass!
#
# Not enough obs for 6403193. pass!
#
# Not enough obs for 6429331. pass!
#
# Not enough obs for 6430456. pass!
#
# Not enough obs for 6434505. pass!
#
# Not enough obs for 6436697. pass!
#
# Not enough obs for 6437801. pass!
#
# Not enough obs for 6465036. pass!
#
# Not enough obs for 6470465. pass!
#
# Not enough obs for 6490900. pass!
#
# Not enough obs for 6491293. pass!
#
# Not enough obs for 6495991. pass!
#
# Not enough obs for 6498843. pass!
#
# Not enough obs for 6509835. pass!
#
# Not enough obs for 6511746. pass!
#
# Not enough obs for 6522731. pass!
#
# Not enough obs for 6536945. pass!
#
# Not enough obs for 6550910. pass!
#
# Not enough obs for 6558014. pass!
#
# Not enough obs for 6558193. pass!
#
# Not enough obs for 6561801. pass!
#
# Not enough obs for 6569737. pass!
#
# Not enough obs for 6575431. pass!
#
# Not enough obs for 6577109. pass!
#
# Not enough obs for 6577931. pass!
#
# Not enough obs for 6584279. pass!
#
# Not enough obs for 6587379. pass!
#
# Not enough obs for 6606751. pass!
#
# Not enough obs for 6609189. pass!
#
# Not enough obs for 6611503. pass!
#
# Not enough obs for 6645315. pass!
#
# Not enough obs for 6651720. pass!
#
# Not enough obs for 6660282. pass!
#
# Not enough obs for 6675508. pass!
#
# Not enough obs for 6692757. pass!
#
# Not enough obs for 6706270. pass!
#
# Not enough obs for 6708882. pass!
#
# Not enough obs for 6708975. pass!
#
# Not enough obs for 6727689. pass!
#
# Not enough obs for 6736636. pass!
#
# Not enough obs for 6751662. pass!
#
# Not enough obs for 6764715. pass!
#
# Not enough obs for 6786414. pass!
#
# Not enough obs for 6787948. pass!
#
# Not enough obs for 6793231. pass!
#
# Not enough obs for 6793930. pass!
#
# Not enough obs for 6802093. pass!
#
# Not enough obs for 6807860. pass!
#
# Not enough obs for 6808779. pass!
#
# Not enough obs for 6818132. pass!
#
# Not enough obs for 8263699. pass!
#
# Not enough obs for 8289382. pass!
#
# Not enough obs for 8291394. pass!
#
# Not enough obs for 8292299. pass!
#
# Not enough obs for 8293024. pass!
#
# Not enough obs for 8304661. pass!
#
# Not enough obs for 8314706. pass!
#
# Not enough obs for 8315131. pass!
#
# Not enough obs for 8332762. pass!
#
# Not enough obs for 8334240. pass!
#
# Not enough obs for 8337981. pass!
#
# Not enough obs for 8340224. pass!
#
# Not enough obs for 8359536. pass!
#
# Not enough obs for 8378138. pass!
#
# Not enough obs for 8384042. pass!
#
# Not enough obs for 8387542. pass!
#
# Not enough obs for 8390950. pass!
#
# Not enough obs for 8403754. pass!
#
# Not enough obs for 8422966. pass!
#
# Not enough obs for 8423980. pass!
#
# Not enough obs for 8424761. pass!
#
# Not enough obs for 8430956. pass!
#
# Not enough obs for 8438166. pass!
#
# Not enough obs for 8442522. pass!
#
# Not enough obs for 8452692. pass!
#
# Not enough obs for 8452809. pass!
#
# Not enough obs for 8463490. pass!
#
# Not enough obs for 8482392. pass!
#
# Not enough obs for 8484819. pass!
#
# Not enough obs for 8493039. pass!
#
# Not enough obs for 8496846. pass!
#
# Not enough obs for 8499769. pass!
#
# Not enough obs for 8506373. pass!
#
# Not enough obs for 8511151. pass!
#
# Not enough obs for 8515922. pass!
#
# Not enough obs for 8516561. pass!
#
# Not enough obs for 8525119. pass!
#
# Not enough obs for 8533537. pass!
#
# Not enough obs for 8535219. pass!
#
# Not enough obs for 8536818. pass!
#
# Not enough obs for 8540621. pass!
#
# Not enough obs for 8544228. pass!
#
# Not enough obs for 8558901. pass!
#
# Not enough obs for 8563232. pass!
#
# Not enough obs for 8575296. pass!
#
# Not enough obs for 8586820. pass!
#
# Not enough obs for 8589091. pass!
#
# Not enough obs for 8590811. pass!
#
# Not enough obs for 8594088. pass!
#
# Not enough obs for 8603161. pass!
#
# Not enough obs for 8604328. pass!
#
# Not enough obs for 8613113. pass!
#
# Not enough obs for 8613817. pass!
#
# Not enough obs for 8624292. pass!
#
# Not enough obs for 8627742. pass!
#
# Not enough obs for 8640316. pass!
#
# Not enough obs for 8646589. pass!
#
# Not enough obs for 8647386. pass!
#
# Not enough obs for 8649752. pass!
#
# Not enough obs for 8654263. pass!
#
# Not enough obs for 8668602. pass!
#
# Not enough obs for 8672500. pass!
#
# Not enough obs for 8673971. pass!
#
# Not enough obs for 8678040. pass!
#
# Not enough obs for 8706122. pass!
#
# Not enough obs for 8722015. pass!
#
# Not enough obs for 8726559. pass!
#
# Not enough obs for 8726733. pass!
#
# Not enough obs for 8731092. pass!
#
# Not enough obs for 8733820. pass!
#
# Not enough obs for 8736275. pass!
#
# Not enough obs for 8748250. pass!
#
# Not enough obs for 8752433. pass!
#
# Not enough obs for 8762582. pass!
#
# Not enough obs for 8766405. pass!
#
# Not enough obs for 8766539. pass!
#
# Not enough obs for 8766955. pass!
#
# Not enough obs for 8803018. pass!
#
# Not enough obs for 8813781. pass!
#
# Not enough obs for 8822824. pass!
#
# Not enough obs for 8834163. pass!
#
# Not enough obs for 8854308. pass!
#
# Not enough obs for 8860347. pass!
#
# Not enough obs for 8863620. pass!
#
# Not enough obs for 8874343. pass!
#
# Not enough obs for 8875422. pass!
#
# Not enough obs for 8877098. pass!
#
# Not enough obs for 8884556. pass!
#
# Not enough obs for 8923047. pass!
#
# Not enough obs for 8930371. pass!
#
# Not enough obs for 8937493. pass!
#
# Not enough obs for 8938176. pass!
#
# Not enough obs for 8939437. pass!
#
# Not enough obs for 8948831. pass!
#
# Not enough obs for 8967793. pass!
#
# Not enough obs for 8979227. pass!
#
# Not enough obs for 8985932. pass!
#
# Not enough obs for 9003194. pass!
#
# Not enough obs for 9013225. pass!
#
# Not enough obs for 9013783. pass!
#
# Not enough obs for 9026491. pass!
#
# Not enough obs for 9029174. pass!
#
# Not enough obs for 9033015. pass!
#
# Not enough obs for 9034619. pass!
#
# Not enough obs for 9042955. pass!
#
# Not enough obs for 9043271. pass!
#
# Not enough obs for 9046289. pass!
#
# Not enough obs for 9055771. pass!
#
# Not enough obs for 9067495. pass!
#
# Not enough obs for 9094744. pass!
#
# Not enough obs for 9098704. pass!
#
# Not enough obs for 9104926. pass!
#
# Not enough obs for 9112463. pass!
#
# Not enough obs for 9118125. pass!
#
# Not enough obs for 9133865. pass!
#
# Not enough obs for 9144000. pass!
#
# Not enough obs for 9152492. pass!
#
# Not enough obs for 9166241. pass!
#
# Not enough obs for 9190706. pass!
#
# Not enough obs for 9192029. pass!
#
# Not enough obs for 9193659. pass!
#
# Not enough obs for 9198003. pass!
#
# Not enough obs for 9206793. pass!
#
# Not enough obs for 9215770. pass!
#
# Not enough obs for 9219190. pass!
#
# Not enough obs for 9220370. pass!
#
# Not enough obs for 9231773. pass!
#
# Not enough obs for 9237360. pass!
#
# Not enough obs for 9243622. pass!
#
# Not enough obs for 9244534. pass!
#
# Not enough obs for 9251598. pass!
#
# Not enough obs for 9262459. pass!
#
# Not enough obs for 9270716. pass!
#
# Not enough obs for 9272901. pass!
#
# Not enough obs for 9286337. pass!
#
# Not enough obs for 9288060. pass!
#
# Not enough obs for 9289179. pass!
#
# Not enough obs for 9310635. pass!
#
# Not enough obs for 9317515. pass!
#
# Not enough obs for 9337033. pass!
#
# Not enough obs for 9350857. pass!
#
# Not enough obs for 9351848. pass!
#
# Not enough obs for 9369227. pass!
#
# Not enough obs for 9370239. pass!
#
# Not enough obs for 9378126. pass!
#
# Not enough obs for 9399401. pass!
#
# Not enough obs for 9415911. pass!
#
# Not enough obs for 9417142. pass!
#
# Not enough obs for 9418816. pass!
#
# Not enough obs for 9425070. pass!
#
# Not enough obs for 9444291. pass!
#
# Not enough obs for 9445732. pass!
#
# Not enough obs for 9447951. pass!
#
# Not enough obs for 9453266. pass!
#
# Not enough obs for 9461961. pass!
#
# Not enough obs for 9476592. pass!
#
# Not enough obs for 9479755. pass!
#
# Not enough obs for 9485806. pass!
#
# Not enough obs for 9488730. pass!
#
# Not enough obs for 9493044. pass!
#
# Not enough obs for 9500835. pass!
#
# Not enough obs for 9508698. pass!
#
# Not enough obs for 9510586. pass!
#
# Not enough obs for 9515664. pass!
#
# Not enough obs for 9527980. pass!
#
# Not enough obs for 9532631. pass!
#
# Not enough obs for 9538368. pass!
#
# Not enough obs for 9542616. pass!
#
# Not enough obs for 9558523. pass!
#
# Not enough obs for 9585448. pass!
#
# Not enough obs for 9586116. pass!
#
# Not enough obs for 9598999. pass!
#
# Not enough obs for 9599081. pass!
#
# Not enough obs for 9625479. pass!
#
# Not enough obs for 9628285. pass!
#
# Not enough obs for 9641768. pass!
#
# Not enough obs for 9659176. pass!
#
# Not enough obs for 9687447. pass!
#
# Not enough obs for 9704046. pass!
#
# Not enough obs for 9713210. pass!
#
# Not enough obs for 9739527. pass!
#
# Not enough obs for 9742746. pass!
#
# Not enough obs for 9746442. pass!
#
# Not enough obs for 9751171. pass!
#
# Not enough obs for 9754920. pass!
#
# Not enough obs for 9765046. pass!
#
# Not enough obs for 9774288. pass!
#
# Not enough obs for 9784118. pass!
#
# Not enough obs for 9784397. pass!
#
# Not enough obs for 9786953. pass!
#
# Not enough obs for 9793434. pass!
#
# Not enough obs for 9797398. pass!
#
# Not enough obs for 9808762. pass!
#
# Not enough obs for 9822633. pass!
#
# Not enough obs for 9835719. pass!
#
# Not enough obs for 9845557. pass!
#
# Not enough obs for 9859749. pass!
#
# Not enough obs for 9862243. pass!
#
# Not enough obs for 9862633. pass!
#
# Not enough obs for 9865168. pass!
#
# Not enough obs for 9877383. pass!
#
# Not enough obs for 9878123. pass!
#
# Not enough obs for 9887253. pass!
#
# Not enough obs for 9893714. pass!
#
# Not enough obs for 9897355. pass!
#
# Not enough obs for 9900732. pass!
#
# Not enough obs for 9915330. pass!
#
# Not enough obs for 9926022. pass!
#
# Not enough obs for 9927486. pass!
#
# Not enough obs for 9930823. pass!
#
# Not enough obs for 9930975. pass!
#
# Not enough obs for 9935474. pass!
#
# Not enough obs for 9938279. pass!
#
# Not enough obs for 9941800. pass!
#
# Not enough obs for 9948809. pass!
#
# Not enough obs for 9956486. pass!
#
# Not enough obs for 9956497. pass!
#
# Not enough obs for 9966293. pass!
#
# Not enough obs for 9967248. pass!
#
# Not enough obs for 9969715. pass!
#
# Not enough obs for 9973499. pass!
#
# Not enough obs for 9975460. pass!
#
# Not enough obs for 9978622. pass!
#
# Not enough obs for 9983538. pass!
#
# Not enough obs for 9984157. pass!
#
# Not enough obs for 9991520. pass!
#
# Not enough obs for 10004144. pass!
#
# Not enough obs for 10009342. pass!
#
# Not enough obs for 10024811. pass!
#
# Not enough obs for 10043291. pass!
#
# Not enough obs for 10048221. pass!
#
# Not enough obs for 10049486. pass!
#
# Not enough obs for 10049961. pass!
#
# Not enough obs for 10058085. pass!
#
# Not enough obs for 10061118. pass!
#
# Not enough obs for 10085457. pass!
#
# Not enough obs for 10104959. pass!
#
# Not enough obs for 10105811. pass!
#
# Not enough obs for 10112690. pass!
#
# Not enough obs for 10119084. pass!
#
# Not enough obs for 10123058. pass!
#
# Not enough obs for 157931664. pass!
#
# Not enough obs for 157938075. pass!
#
# Not enough obs for 157949587. pass!
#
# Not enough obs for 157957987. pass!
#
# Not enough obs for 157960544. pass!
#
# Not enough obs for 157966294. pass!
#
# Not enough obs for 157969889. pass!
#
# Not enough obs for 157988350. pass!
#
# Not enough obs for 157991728. pass!
#
# Not enough obs for 157994898. pass!
#
# Not enough obs for 158008994. pass!
#
# Not enough obs for 158011043. pass!
#
# Not enough obs for 158023122. pass!
#
# Not enough obs for 158037645. pass!
#
# Not enough obs for 158052278. pass!
#
# Not enough obs for 158057768. pass!
#
# Not enough obs for 158063757. pass!
#
# Not enough obs for 158068597. pass!
#
# Not enough obs for 158079587. pass!
#
# Not enough obs for 158087572. pass!
#
# Not enough obs for 158088768. pass!
#
# Not enough obs for 158104759. pass!
#
# Not enough obs for 158108309. pass!
#
# Not enough obs for 158124584. pass!
#
# Not enough obs for 158129971. pass!
#
# Not enough obs for 158137431. pass!
#
# Not enough obs for 158141618. pass!
#
# Not enough obs for 158142710. pass!
#
# Not enough obs for 158144780. pass!
#
# Not enough obs for 158146871. pass!
#
# Not enough obs for 158154809. pass!
#
# Not enough obs for 158160142. pass!
#
# Not enough obs for 158170303. pass!
#
# Not enough obs for 158170762. pass!
#
# Not enough obs for 158176433. pass!
#
# Not enough obs for 158182949. pass!
#
# Not enough obs for 158195042. pass!
#
# Not enough obs for 158207946. pass!
#
# Not enough obs for 158219624. pass!
#
# Not enough obs for 158222613. pass!
#
# Not enough obs for 158241828. pass!
#
# Not enough obs for 158260156. pass!
#
# Not enough obs for 158268521. pass!
#
# Not enough obs for 158270743. pass!
#
# Not enough obs for 158277340. pass!
#
# Not enough obs for 158284168. pass!
#
# Not enough obs for 158287703. pass!
#
# Not enough obs for 158293030. pass!
#
# Not enough obs for 158320012. pass!
#
# Not enough obs for 158327227. pass!
#
# Not enough obs for 158332477. pass!
#
# Not enough obs for 158380673. pass!
#
# Not enough obs for 158383207. pass!
#
# Not enough obs for 158393169. pass!
#
# Not enough obs for 158403725. pass!
#
# Not enough obs for 158411000. pass!
#
# Not enough obs for 158413601. pass!
#
# Not enough obs for 158422336. pass!
#
# Not enough obs for 158426325. pass!
#
# Not enough obs for 158427909. pass!
#
# Not enough obs for 158435729. pass!
#
# Not enough obs for 158436585. pass!
#
# Not enough obs for 158461101. pass!
#
# Not enough obs for 158463144. pass!
#
# Not enough obs for 158464105. pass!
#
# Not enough obs for 158475963. pass!
#
# Not enough obs for 158476006. pass!
#
# Not enough obs for 158479863. pass!
#
# Not enough obs for 158515021. pass!
#
# Not enough obs for 158515643. pass!
#
# Not enough obs for 158530531. pass!
#
# Not enough obs for 158537369. pass!
#
# Not enough obs for 158538721. pass!
#
# Not enough obs for 158557044. pass!
#
# Not enough obs for 158561244. pass!
#
# Not enough obs for 158571966. pass!
#
# Not enough obs for 158586443. pass!
#
# Not enough obs for 158600887. pass!
#
# Not enough obs for 158611496. pass!
#
# Not enough obs for 158612401. pass!
#
# Not enough obs for 158615345. pass!
# Not enough obs for 159262378. pass!
#
# Not enough obs for 159265636. pass!
#
# Not enough obs for 159274814. pass!
#
# Not enough obs for 159277299. pass!
#
# Not enough obs for 159278727. pass!
#
# Not enough obs for 159279215. pass!
#
# Not enough obs for 159280362. pass!
#
# Not enough obs for 159324048. pass!
#
# Not enough obs for 159324836. pass!
#
# Not enough obs for 159365967. pass!
#
# Not enough obs for 159374419. pass!
#
# Not enough obs for 159385952. pass!
#
# Not enough obs for 159398105. pass!
#
# Not enough obs for 159405630. pass!
#
# Not enough obs for 159427375. pass!
#
# Not enough obs for 159436137. pass!
#
# Not enough obs for 159458498. pass!
#
# Not enough obs for 159466010. pass!
#
# Not enough obs for 159481764. pass!
#
# Not enough obs for 159484812. pass!
#
# Not enough obs for 159489472. pass!
#
# Not enough obs for 159494076. pass!
#
# Not enough obs for 159497868. pass!
#
# Not enough obs for 159504277. pass!
#
# Not enough obs for 159506341. pass!
# INFO:root:Starting laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor fit...
# INFO:root:Features have been saved to: TOM_days_storage/TOM_hot_features_day_50.csv

# %%
def run_td_loop(day):
    # feature_extraction_method = 'Malanchev'
    feature_extraction_method = 'laiss_resspect_classifier.elasticc2_laiss_feature_extractor.Elasticc2LaissFeatureExtractor'
    # classifier = 'RandomForest'
    classifier = 'laiss_resspect_classifier.laiss_classifier.LaissRandomForest'
    
    # run the loop to get queried objects and updated metrics
    days = [day-1, day+1]                                # first and last day of the survey
    training = None                           # if int take int number of objs
                                                        # for initial training, 50% being Ia
    
    strategy = 'CertaintySampling'                        # learning strategy
    batch = 5                                       # if int, ignore cost per observation,
                                                         # if None find optimal batch size
    
    sep_files = True                               # if True, expects train, test and
                                                        # validation samples in separate filess
    
    path_to_features_dir = 'TOM_days_storage/'   # folder where the files for each day are stored
    
    # output results for metrics
    output_metrics_file = 'results/metrics_' + strategy + '_' + str('ini_train_set') + \
                           '_batch' + str(batch) +  '.csv'
    
    # output query sample
    output_query_file = 'results/queried_' + strategy + '_' + str('ini_train_set') + \
                            '_batch' + str(batch) + '_day_'+ str(day) + '.csv'
    
    path_to_ini_files = {}
    
    # features from full light curves for initial training sample
    path_to_ini_files['train'] = 'TOM_days_storage/TOM_training_features'
    path_to_ini_files['test'] = 'TOM_days_storage/TOM_testing_features'
    path_to_ini_files['validation'] = 'TOM_days_storage/TOM_validation_features'

    survey='ZTF'

    n_estimators = 1000                             # number of trees in the forest

    screen = False                                  # if True will print many things for debuging
    fname_pattern = ['TOM_hot_features_day_', '.csv']                # pattern on filename where different days
                                                        # are stored
    
    queryable= False                                 # if True, check brightness before considering
                                                        # an object queryable    
    
    # run time domain loop
    time_domain_loop(TimeDomainConfiguration(days=days, output_metrics_file=output_metrics_file,
                     output_queried_file=output_query_file,
                     path_to_ini_files=path_to_ini_files,
                     path_to_features_dir=path_to_features_dir,
                     strategy=strategy, fname_pattern=fname_pattern, batch=batch,
                     classifier=classifier,
                     sep_files=sep_files,
                     survey=survey, queryable=queryable,
                     feature_extraction_method=feature_extraction_method),
                     screen=screen, n_estimators=n_estimators,
                     )

    #🔲 do we want higher entropy in our returned objects?
    # Read in RESSPECT requests to input to TOM format
    ids = list(pd.read_csv(output_query_file)['objectid'])
    ids = [int(id) for id in ids]
    num = int(len(ids)/5)
    mod = len(ids)%5
    num_list = [num]*5
    mod_list = []
    for i in range(mod):
        mod_list.append(1)
    rem = 5-len(mod_list)
    mod_list = mod_list+[0]*rem
    num_list=list(np.asarray(num_list)+mod_list)
    priorities = []
    priorities.append([1]*num_list[0]+[2]*num_list[1]+[3]*num_list[2]+[4]*num_list[3]+[5]*num_list[4])    
    priorities = priorities[0]
    
    # send these queried objects to the TOM
    # submit_queries_to_TOM('awoldag', '../../password.txt', objectids = ids, priorities = priorities, requester = 'resspect')
    print(ids, priorities)

# %%
run_td_loop(50)
# Out:
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:01 Time:  0:00:01
# [135887774, 117635023, 4949578, 129006369] [1, 2, 3, 4]

# %%
#Pull classified obj and add them to the training set
def get_classified(username, passwordfile=None, password=None, since = None):
    tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = username, password = password, 
                    passwordfile = passwordfile)
    dic = {}
    if since is not None:
        dic['since'] = since

    res = tom.post( 'elasticc2/getknownspectruminfo', json=dic )

    assert res.status_code == 200
    assert res.json()['status'] == "ok"
    reqs = res.json()
    return reqs

# %%
classed_obj = get_classified('amandaw8', passwordfile='/Users/arw/secrets/TOM2', since = '11/22/2024 19:20:00')

# %%
objectids = []
classes = []
for obj in classed_obj['spectra']:
    objectids.append(obj['objectid'])
    if obj['classid'] == 2222:
        classes.append('Ia')
    else:
        classes.append('other')

# %%
def get_object_phot(username, passwordfile=None, password=None, obj_ids=[]):
    tom = TomClient(url = "https://desc-tom-2.lbl.gov", username = username, password = password, 
                    passwordfile = passwordfile)
    dic = {'obj_ids': obj_ids}

    res = tom.post( 'elasticc2/getobjphot', json = dic)

    assert res.status_code == 200
    assert res.json()['status'] == "ok"
    reqs = res.json()
    return reqs

# %%
def update_training_set(objectids, classes):
    #need to fetch the current features of the labeled objs (probably from the TOM, get the features and format correctly) 
    #! figure out how to get a specific objid photometry
    #IN THE FUTURE get this from our mongodb, in the mean time though only god knows which files will contain which objects


    # call something like elasticc2/getobjphot
    data_dic = get_object_phot(amandaw8, passwordfile = '/Users/arw/secrets/tom2', obj_ids = objectids)

    # put the ^ dictionary into the right format to get features
    data_dic=data_dic['diaobject'] 
    
    # then do something like fit_TOM to get the features from the object photometry
    outdir = 'TOM_train_features_storage'
    file_name = outdir+'/TOM_train_features_day_'+str(day)+'.csv'
        
    fit_TOM(data_dic, output_features_file = file_name, feature_extractor = 'Malanchev')
    data = pd.read_csv(file_name, index_col=False)
    data['orig_sample'] = 'train'
    
    data.to_csv(file_name,index=False)

    # then do something like read this file in and concatenate it with the current training set



    
    #REMOVE classified objects from the pool set each night. Just double check that 
    #all SN in hot transients DO NOT have same object ids as those in the training set
    #CHECK WITH ROB - can we make it so that gethotsne removed classified obj

# %%
import progressbar
import time

for i in progressbar.progressbar(range(10)):
    time.sleep(0.1)
